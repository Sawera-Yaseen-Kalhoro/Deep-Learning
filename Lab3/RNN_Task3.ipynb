# %%
import sys
sys.path.append('/content/drive/MyDrive/Lab3')
sys.path.append('/content/drive/MyDrive/Lab3/data')

# %%
import random
import importlib
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from dataloader import *
from colors import *

# %%
class Recurrent(nn.Module):
    def __init__(self, type='GRU', hidden_size=150, num_layers=2, dropout=0.5, bidirectional=False):
        super(Recurrent, self).__init__()

        self.type = type
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.dropout = dropout
        self.bidirectional = bidirectional

        if self.type == 'GRU':
            self.rnn = nn.GRU(input_size=300,
                              hidden_size=self.hidden_size,
                              batch_first=False,
                              num_layers=self.num_layers,
                              dropout=self.dropout,
                              bidirectional=self.bidirectional)
        elif self.type == 'LSTM':
            self.rnn = nn.LSTM(input_size=300,
                               hidden_size=self.hidden_size,
                               batch_first=False,
                               num_layers=self.num_layers,
                               dropout=self.dropout,
                               bidirectional=self.bidirectional)
        else:
            self.rnn = nn.RNN(input_size=300,
                              hidden_size=self.hidden_size,
                              batch_first=False,
                              num_layers=self.num_layers,
                              dropout=self.dropout,
                              bidirectional=self.bidirectional)

        self.fc1 = nn.Linear(self.hidden_size, self.hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(self.hidden_size, 1) # Outputs a single value (for binary classification)


    def forward(self, x):
      """
      Forward pass for the recurrent neural network.

      Args:
          x (torch.Tensor): Input tensor of shape (seq_len, batch_size, input_size),
                            where seq_len is the length of the sequence,
                            batch_size is the number of samples in a batch,
                            and input_size is the size of word embeddings (300 for GloVe).

      Returns:
          torch.Tensor: The output tensor of shape (batch_size, 1),
                        representing raw logits for each sample in the batch.
      """

      # Pass the input sequence through the RNN layer (LSTM, GRU, or RNN)
      if self.type == 'LSTM':
          # LSTM returns (all_hidden_states, (all hidden states,(final hidden state,final cell state))
          _, (x, _) = self.rnn(x)  # We only take the final hidden state (x), ignoring cell state (_)
      else:
          # GRU and vanilla RNN return (all_hidden_states, final_hidden_state)
          _, x = self.rnn(x)  # We only take the final hidden state (x)

      # Extract the last layer's hidden state
      # The RNN outputs hidden states for all layers, but we only need the last layer
      x = x[-1]  # Shape: (batch_size, hidden_size)

      x = self.fc1(x)  # Shape: (batch_size, hidden_size)

      x = self.relu(x)  # Shape: (batch_size, hidden_size)

      x = self.fc2(x)  # Shape: (batch_size, 1) - single output per sample

      return x  # Output logits (raw scores)

# %%
def train(model, dataloader, epochs, optimizer, loss_fcn, embeddings, validation_dataloader, device):
    print('Training Started')
    model.train()

    for epoch in range(epochs):
      model.train()
      total_loss = 0
      for i, (words, labels, lengths) in enumerate(dataloader):
        optimizer.zero_grad()

        # Move data to the GPU
        words, labels = words.to(device), labels.to(device)

        words = words.type(torch.LongTensor).to(device)
        words = embeddings(words).to(device)
        words = words.transpose(1, 0)

        output = model.forward(words).squeeze()
        loss = loss_fcn(output, labels)
        total_loss += loss.item()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.25)
        optimizer.step()

      accuracy, CM, precision, recall, f1 = evaluate(model, validation_dataloader, loss_fcn, embeddings, device)
      print(Colors.RED + f'Epoch {epoch}: Valid accuracy: {accuracy.item()}' + Colors.RESET)

    print('Finished Training')
    return accuracy, precision, recall, f1


def evaluate(model, dataloader, loss_fcn, embeddings, device):
    model.eval()
    confusion_matrix = torch.zeros(2, 2).to(device)

    with torch.no_grad():
        for i, (words, labels, lengths) in enumerate(dataloader):
            words, labels = words.to(device), labels.to(device)

            words = words.type(torch.LongTensor).to(device)
            words = embeddings(words).to(device)
            words = words.transpose(1, 0)

            output = model.forward(words).squeeze()
            predictions = torch.round(torch.sigmoid(output))
            for i in range(len(predictions)):
                confusion_matrix[int(labels[i]), int(predictions[i])] += 1

    accuracy = confusion_matrix.diag().sum() / confusion_matrix.sum()
    precision = confusion_matrix[0, 0] / confusion_matrix[0, :].sum()
    recall = confusion_matrix[0, 0] / confusion_matrix[:, 0].sum()
    f1 = 2 * precision * recall / (precision + recall)

    return accuracy, confusion_matrix, precision, recall, f1

# %%
if __name__ == '__main__':
    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    print(f'Using device: {device}')

    seed = 7052020
    torch.manual_seed(seed)
    np.random.seed(seed)
    batch_size = 10
    shuffle = True

    train_dataset = NLPDataset('/content/drive/MyDrive/Lab3/data/sst_train_raw.csv', train=True)
    train_dataloader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=shuffle, collate_fn=pad_collate_fn)

    text_vocab = Vocab(train_dataset.text_frequencies, max_size=-1, min_freq=0)
    label_vocab = Vocab(train_dataset.label_frequencies, max_size=-1, min_freq=0)

    test_dataset = NLPDataset('/content/drive/MyDrive/Lab3/data/sst_test_raw.csv', train=False, text_vocab=text_vocab, label_vocab=label_vocab)
    test_dataloader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=shuffle, collate_fn=pad_collate_fn)

    validation_dataset = NLPDataset('/content/drive/MyDrive/Lab3/data/sst_valid_raw.csv', train=False, text_vocab=text_vocab, label_vocab=label_vocab)
    validation_dataloader = DataLoader(dataset=validation_dataset, batch_size=len(validation_dataset), collate_fn=pad_collate_fn)

    word_rep = load_embeddings('/content/drive/MyDrive/Lab3/data/sst_glove_6b_300d.txt')
    word_embeddings = gen_embeddings(text_vocab.stoi, word_rep).to(device)

    loss_fcn = nn.BCEWithLogitsLoss()

    cell_type = ['LSTM', 'GRU', 'RNN']
    hidden_size = [50, 100, 150, 200, 250, 300, 350, 400, 450, 500]
    num_layers = [2, 3, 4, 5, 6, 7, 8, 9, 10]
    dropout = [0.0, 0.15, 0.25, 0.35, 0.5, 0.65, 0.75, 0.85]
    bidirectional = [True, False]
    results = []


    # Test different seeds
    for i in range(5):
        hidden = 100
        layers = 3
        drop = 0.35
        bi_dir = True

        print(Colors.BLUE + f'Cell type: LSTM, Hidden_size: {hidden}, Num layers: {layers}, Dropout: {drop}, Bidirectional: {bi_dir}' + Colors.RESET)

        model = Recurrent(type='LSTM', hidden_size=hidden, num_layers=layers, dropout=drop, bidirectional=bi_dir).to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
        accuracy, precision, recall, f1 = train(model, train_dataloader, 5, optimizer, loss_fcn, word_embeddings, validation_dataloader, device)
        accuracy = round(accuracy.item() * 100, 2)
        results.append((seed, 'LSTM', accuracy, precision.item(), recall.item(), f1.item()))
        seed = random.randint(0, 1000000)
        torch.manual_seed(seed)
        np.random.seed(seed)

    test_accuracy, test_CM, test_precision, test_recall, test_f1 = evaluate(model, test_dataloader, loss_fcn, word_embeddings, device)
    print(f'Test Accuracy: {test_accuracy.item()}')

    # Save seed results
    with open('/content/drive/MyDrive/Lab3/results/good_cell_seeds_LSTM.txt', 'w') as f:
        for item in results:
            f.write(f'Seed: {item[0]}, Cell: {item[1]}, Accuracy: {item[2]}, Precision: {item[3]}, Recall: {item[4]}, F1: {item[5]}\n')

    """
        For the Task 4
    """

    # Test different parameters
    # for type in cell_type:
    #     for _ in range(15):
    #         hidden = random.choice(hidden_size)
    #         layers = random.choice(num_layers)
    #         drop = random.choice(dropout)
    #         bi_dir = random.choice(bidirectional)

    #         print(Colors.BLUE + f'Cell type: {type}, Hidden_size: {hidden}, Num layers: {layers}, Dropout: {drop}, Bidirectional: {bi_dir}' + Colors.RESET)

    #         model = Recurrent(type=type, hidden_size=hidden, num_layers=layers, dropout=drop, bidirectional=bi_dir).to(device)
    #         optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

    #         accuracy, f1, _, _ = train(model, train_dataloader, 5, optimizer, loss_fcn, word_embeddings, validation_dataloader, device)
    #         accuracy = round(accuracy.item() * 100, 2)
    #         results.append((type, hidden, layers, drop, bi_dir, accuracy, f1.item()))

    # # Save parameter results
    # with open('/content/drive/MyDrive/Lab3/results/rnn_params.txt', 'w') as f:
    #     for item in results:
    #         f.write(f'Cell type: {item[0]}, Hidden size: {item[1]}, Num layers: {item[2]}, Dropout: {item[3]}, Bidirectional: {item[4]}, Accuracy: {item[5]}, F1: {item[6]}\n')
# Out:
# Streaming output truncated to the last 5000 lines.
# word: rigidly index: 12136
# word rigidly is in word_rep at index 12136
# word: paradigm index: 12137
# word paradigm is in word_rep at index 12137
# word: permitting index: 12138
# word permitting is in word_rep at index 12138
# word: well-worn index: 12139
# word well-worn is in word_rep at index 12139
# word: bmw index: 12140
# word bmw is in word_rep at index 12140
# word: haranguing index: 12141
# word haranguing is in word_rep at index 12141
# word: squashed index: 12142
# word squashed is in word_rep at index 12142
# word: preferably index: 12143
# word preferably is in word_rep at index 12143
# word: semi index: 12144
# word semi is in word_rep at index 12144
# word: re-hash index: 12145
# word: jump index: 12146
# word jump is in word_rep at index 12146
# word: nausea index: 12147
# word nausea is in word_rep at index 12147
# word: dull-witted index: 12148
# word: disquietingly index: 12149
# word disquietingly is in word_rep at index 12149
# word: jams index: 12150
# word jams is in word_rep at index 12150
# word: prefabricated index: 12151
# word prefabricated is in word_rep at index 12151
# word: bailiwick index: 12152
# word bailiwick is in word_rep at index 12152
# word: self-righteous index: 12153
# word self-righteous is in word_rep at index 12153
# word: monopoly index: 12154
# word monopoly is in word_rep at index 12154
# word: disconcertingly index: 12155
# word disconcertingly is in word_rep at index 12155
# word: oblivious index: 12156
# word oblivious is in word_rep at index 12156
# word: sweep index: 12157
# word sweep is in word_rep at index 12157
# word: choppiness index: 12158
# word choppiness is in word_rep at index 12158
# word: unseemly index: 12159
# word unseemly is in word_rep at index 12159
# word: congratulate index: 12160
# word congratulate is in word_rep at index 12160
# word: college-spawned index: 12161
# word: colgate index: 12162
# word colgate is in word_rep at index 12162
# word: u. index: 12163
# word u. is in word_rep at index 12163
# word: cheech index: 12164
# word cheech is in word_rep at index 12164
# word: chong index: 12165
# word chong is in word_rep at index 12165
# word: restage index: 12166
# word restage is in word_rep at index 12166
# word: bathtub index: 12167
# word bathtub is in word_rep at index 12167
# word: quickie index: 12168
# word quickie is in word_rep at index 12168
# word: slickly index: 12169
# word slickly is in word_rep at index 12169
# word: antiseptic index: 12170
# word antiseptic is in word_rep at index 12170
# word: insensitivity index: 12171
# word insensitivity is in word_rep at index 12171
# word: groundbreaking index: 12172
# word groundbreaking is in word_rep at index 12172
# word: thirty-three index: 12173
# word thirty-three is in word_rep at index 12173
# word: explanations index: 12174
# word explanations is in word_rep at index 12174
# word: overrides index: 12175
# word overrides is in word_rep at index 12175
# word: vicarious index: 12176
# word vicarious is in word_rep at index 12176
# word: paramount index: 12177
# word paramount is in word_rep at index 12177
# word: imprint index: 12178
# word imprint is in word_rep at index 12178
# word: sewer index: 12179
# word sewer is in word_rep at index 12179
# word: rats index: 12180
# word rats is in word_rep at index 12180
# word: skeeved index: 12181
# word: mattel index: 12182
# word mattel is in word_rep at index 12182
# word: executives index: 12183
# word executives is in word_rep at index 12183
# word: lobbyists index: 12184
# word lobbyists is in word_rep at index 12184
# word: tinsel index: 12185
# word tinsel is in word_rep at index 12185
# word: martial-arts index: 12186
# word martial-arts is in word_rep at index 12186
# word: forte index: 12187
# word forte is in word_rep at index 12187
# word: underdog index: 12188
# word underdog is in word_rep at index 12188
# word: sufficient index: 12189
# word sufficient is in word_rep at index 12189
# word: leroy index: 12190
# word leroy is in word_rep at index 12190
# word: greaseballs index: 12191
# word: louiso index: 12192
# word louiso is in word_rep at index 12192
# word: dawdle index: 12193
# word dawdle is in word_rep at index 12193
# word: disaffected-indie-film index: 12194
# word: mode index: 12195
# word mode is in word_rep at index 12195
# word: late-inning index: 12196
# word late-inning is in word_rep at index 12196
# word: straddles index: 12197
# word straddles is in word_rep at index 12197
# word: boldface index: 12198
# word boldface is in word_rep at index 12198
# word: obscenely index: 12199
# word obscenely is in word_rep at index 12199
# word: sidewalks index: 12200
# word sidewalks is in word_rep at index 12200
# word: foundering index: 12201
# word foundering is in word_rep at index 12201
# word: patchy index: 12202
# word patchy is in word_rep at index 12202
# word: low-tech index: 12203
# word low-tech is in word_rep at index 12203
# word: happenstance index: 12204
# word happenstance is in word_rep at index 12204
# word: overladen index: 12205
# word overladen is in word_rep at index 12205
# word: talked index: 12206
# word talked is in word_rep at index 12206
# word: servitude index: 12207
# word servitude is in word_rep at index 12207
# word: skirts index: 12208
# word skirts is in word_rep at index 12208
# word: frustrations index: 12209
# word frustrations is in word_rep at index 12209
# word: sitcom-worthy index: 12210
# word: overstylized index: 12211
# word: puréed index: 12212
# word: mélange index: 12213
# word mélange is in word_rep at index 12213
# word: malle index: 12214
# word malle is in word_rep at index 12214
# word: messing index: 12215
# word messing is in word_rep at index 12215
# word: slob index: 12216
# word slob is in word_rep at index 12216
# word: reductions index: 12217
# word reductions is in word_rep at index 12217
# word: runyon index: 12218
# word runyon is in word_rep at index 12218
# word: crooks index: 12219
# word crooks is in word_rep at index 12219
# word: wasting index: 12220
# word wasting is in word_rep at index 12220
# word: legally index: 12221
# word legally is in word_rep at index 12221
# word: blonde index: 12222
# word blonde is in word_rep at index 12222
# word: abomination index: 12223
# word abomination is in word_rep at index 12223
# word: smell index: 12224
# word smell is in word_rep at index 12224
# word: grease index: 12225
# word grease is in word_rep at index 12225
# word: hairier index: 12226
# word hairier is in word_rep at index 12226
# word: einstein index: 12227
# word einstein is in word_rep at index 12227
# word: sympathizing index: 12228
# word sympathizing is in word_rep at index 12228
# word: screed index: 12229
# word screed is in word_rep at index 12229
# word: uwe index: 12230
# word uwe is in word_rep at index 12230
# word: blah index: 12231
# word blah is in word_rep at index 12231
# word: literarily index: 12232
# word literarily is in word_rep at index 12232
# word: hard-partying index: 12233
# word: fetid index: 12234
# word fetid is in word_rep at index 12234
# word: uglier index: 12235
# word uglier is in word_rep at index 12235
# word: homosexual index: 12236
# word homosexual is in word_rep at index 12236
# word: tv-insider index: 12237
# word: endorses index: 12238
# word endorses is in word_rep at index 12238
# word: scribe index: 12239
# word scribe is in word_rep at index 12239
# word: wade index: 12240
# word wade is in word_rep at index 12240
# word: workmanlike index: 12241
# word workmanlike is in word_rep at index 12241
# word: recognized index: 12242
# word recognized is in word_rep at index 12242
# word: bilked index: 12243
# word bilked is in word_rep at index 12243
# word: overacted index: 12244
# word overacted is in word_rep at index 12244
# word: wattage index: 12245
# word wattage is in word_rep at index 12245
# word: conforms index: 12246
# word conforms is in word_rep at index 12246
# word: scarface index: 12247
# word scarface is in word_rep at index 12247
# word: carlito index: 12248
# word carlito is in word_rep at index 12248
# word: period-perfect index: 12249
# word: hammers index: 12250
# word hammers is in word_rep at index 12250
# word: invested index: 12251
# word invested is in word_rep at index 12251
# word: undergraduate index: 12252
# word undergraduate is in word_rep at index 12252
# word: doubling index: 12253
# word doubling is in word_rep at index 12253
# word: subtexts index: 12254
# word subtexts is in word_rep at index 12254
# word: stabs index: 12255
# word stabs is in word_rep at index 12255
# word: wizard index: 12256
# word wizard is in word_rep at index 12256
# word: dilutes index: 12257
# word dilutes is in word_rep at index 12257
# word: stalked index: 12258
# word stalked is in word_rep at index 12258
# word: creepy-crawly index: 12259
# word: bug index: 12260
# word bug is in word_rep at index 12260
# word: predominantly index: 12261
# word predominantly is in word_rep at index 12261
# word: unnamed index: 12262
# word unnamed is in word_rep at index 12262
# word: substitutable index: 12263
# word: ethan index: 12264
# word ethan is in word_rep at index 12264
# word: tempted index: 12265
# word tempted is in word_rep at index 12265
# word: redundancies index: 12266
# word redundancies is in word_rep at index 12266
# word: inexpressive index: 12267
# word inexpressive is in word_rep at index 12267
# word: disagree index: 12268
# word disagree is in word_rep at index 12268
# word: rorschach index: 12269
# word rorschach is in word_rep at index 12269
# word: pie-like index: 12270
# word: irreverence index: 12271
# word irreverence is in word_rep at index 12271
# word: illiterate index: 12272
# word illiterate is in word_rep at index 12272
# word: inert index: 12273
# word inert is in word_rep at index 12273
# word: rancid index: 12274
# word rancid is in word_rep at index 12274
# word: contain index: 12275
# word contain is in word_rep at index 12275
# word: balto index: 12276
# word balto is in word_rep at index 12276
# word: toy index: 12277
# word toy is in word_rep at index 12277
# word: procedural index: 12278
# word procedural is in word_rep at index 12278
# word: horton index: 12279
# word horton is in word_rep at index 12279
# word: gaitskill index: 12280
# word gaitskill is in word_rep at index 12280
# word: evasive index: 12281
# word evasive is in word_rep at index 12281
# word: erin index: 12282
# word erin is in word_rep at index 12282
# word: brockovich index: 12283
# word brockovich is in word_rep at index 12283
# word: eleven index: 12284
# word eleven is in word_rep at index 12284
# word: trimming index: 12285
# word trimming is in word_rep at index 12285
# word: expeditious index: 12286
# word expeditious is in word_rep at index 12286
# word: dumped index: 12287
# word dumped is in word_rep at index 12287
# word: toro index: 12288
# word toro is in word_rep at index 12288
# word: reassure index: 12289
# word reassure is in word_rep at index 12289
# word: vittorio index: 12290
# word vittorio is in word_rep at index 12290
# word: sica index: 12291
# word sica is in word_rep at index 12291
# word: self-exploitation index: 12292
# word: merge index: 12293
# word merge is in word_rep at index 12293
# word: soft-porn index: 12294
# word: powerment index: 12295
# word: genevieve index: 12296
# word genevieve is in word_rep at index 12296
# word: leplouff index: 12297
# word: option index: 12298
# word option is in word_rep at index 12298
# word: creators index: 12299
# word creators is in word_rep at index 12299
# word: laconic index: 12300
# word laconic is in word_rep at index 12300
# word: rancorous index: 12301
# word rancorous is in word_rep at index 12301
# word: gleaned index: 12302
# word gleaned is in word_rep at index 12302
# word: pulchritude index: 12303
# word pulchritude is in word_rep at index 12303
# word: revelled index: 12304
# word revelled is in word_rep at index 12304
# word: shallows index: 12305
# word shallows is in word_rep at index 12305
# word: beside index: 12306
# word beside is in word_rep at index 12306
# word: cousin index: 12307
# word cousin is in word_rep at index 12307
# word: bottom-feeder index: 12308
# word: printed index: 12309
# word printed is in word_rep at index 12309
# word: iles index: 12310
# word iles is in word_rep at index 12310
# word: duking index: 12311
# word duking is in word_rep at index 12311
# word: poky index: 12312
# word poky is in word_rep at index 12312
# word: pseudo-serious index: 12313
# word: workshops index: 12314
# word workshops is in word_rep at index 12314
# word: burkina index: 12315
# word burkina is in word_rep at index 12315
# word: faso index: 12316
# word faso is in word_rep at index 12316
# word: nurtured index: 12317
# word nurtured is in word_rep at index 12317
# word: bottom-rung index: 12318
# word: modem index: 12319
# word modem is in word_rep at index 12319
# word: disconnects index: 12320
# word disconnects is in word_rep at index 12320
# word: critic-proof index: 12321
# word: oh-so index: 12322
# word: cutoffs index: 12323
# word cutoffs is in word_rep at index 12323
# word: reduce index: 12324
# word reduce is in word_rep at index 12324
# word: buries index: 12325
# word buries is in word_rep at index 12325
# word: borrowed index: 12326
# word borrowed is in word_rep at index 12326
# word: flowery index: 12327
# word flowery is in word_rep at index 12327
# word: roads index: 12328
# word roads is in word_rep at index 12328
# word: uncharismatically index: 12329
# word: résumé index: 12330
# word résumé is in word_rep at index 12330
# word: magician index: 12331
# word magician is in word_rep at index 12331
# word: unencouraging index: 12332
# word: threefold index: 12333
# word threefold is in word_rep at index 12333
# word: expansion index: 12334
# word expansion is in word_rep at index 12334
# word: accompanying index: 12335
# word accompanying is in word_rep at index 12335
# word: stunt-hungry index: 12336
# word: dimwits index: 12337
# word dimwits is in word_rep at index 12337
# word: collected index: 12338
# word collected is in word_rep at index 12338
# word: pranks index: 12339
# word pranks is in word_rep at index 12339
# word: joshua index: 12340
# word joshua is in word_rep at index 12340
# word: luis index: 12341
# word luis is in word_rep at index 12341
# word: attendant index: 12342
# word attendant is in word_rep at index 12342
# word: ventura index: 12343
# word ventura is in word_rep at index 12343
# word: pollak index: 12344
# word pollak is in word_rep at index 12344
# word: wrestler index: 12345
# word wrestler is in word_rep at index 12345
# word: chyna index: 12346
# word chyna is in word_rep at index 12346
# word: dolly index: 12347
# word dolly is in word_rep at index 12347
# word: parton index: 12348
# word parton is in word_rep at index 12348
# word: resumes index: 12349
# word resumes is in word_rep at index 12349
# word: puportedly index: 12350
# word: convolution index: 12351
# word convolution is in word_rep at index 12351
# word: lumpy index: 12352
# word lumpy is in word_rep at index 12352
# word: two-day index: 12353
# word two-day is in word_rep at index 12353
# word: paws index: 12354
# word paws is in word_rep at index 12354
# word: un-bear-able index: 12355
# word: appealingly index: 12356
# word appealingly is in word_rep at index 12356
# word: enacted index: 12357
# word enacted is in word_rep at index 12357
# word: self-absorbed index: 12358
# word self-absorbed is in word_rep at index 12358
# word: featured index: 12359
# word featured is in word_rep at index 12359
# word: whiney index: 12360
# word whiney is in word_rep at index 12360
# word: bugged index: 12361
# word bugged is in word_rep at index 12361
# word: omitted index: 12362
# word omitted is in word_rep at index 12362
# word: unsaid index: 12363
# word unsaid is in word_rep at index 12363
# word: ugh index: 12364
# word ugh is in word_rep at index 12364
# word: bug-eye index: 12365
# word: dead-eye index: 12366
# word: journalistic index: 12367
# word journalistic is in word_rep at index 12367
# word: pelosi index: 12368
# word pelosi is in word_rep at index 12368
# word: jeopardy index: 12369
# word jeopardy is in word_rep at index 12369
# word: glass-shattering index: 12370
# word: sexist index: 12371
# word sexist is in word_rep at index 12371
# word: brow index: 12372
# word brow is in word_rep at index 12372
# word: snuck index: 12373
# word snuck is in word_rep at index 12373
# word: joão index: 12374
# word joão is in word_rep at index 12374
# word: pedro index: 12375
# word pedro is in word_rep at index 12375
# word: unwillingness index: 12376
# word unwillingness is in word_rep at index 12376
# word: cheats index: 12377
# word cheats is in word_rep at index 12377
# word: retreats index: 12378
# word retreats is in word_rep at index 12378
# word: thoughtless index: 12379
# word thoughtless is in word_rep at index 12379
# word: scouse index: 12380
# word scouse is in word_rep at index 12380
# word: simpsons index: 12381
# word simpsons is in word_rep at index 12381
# word: wewannour index: 12382
# word: siuation index: 12383
# word: postapocalyptic index: 12384
# word postapocalyptic is in word_rep at index 12384
# word: disadvantage index: 12385
# word disadvantage is in word_rep at index 12385
# word: overstays index: 12386
# word overstays is in word_rep at index 12386
# word: hurry index: 12387
# word hurry is in word_rep at index 12387
# word: uncompelling index: 12388
# word uncompelling is in word_rep at index 12388
# word: decomposition index: 12389
# word decomposition is in word_rep at index 12389
# word: cloak index: 12390
# word cloak is in word_rep at index 12390
# word: romanticization index: 12391
# word romanticization is in word_rep at index 12391
# word: delusional index: 12392
# word delusional is in word_rep at index 12392
# word: semi-autobiographical index: 12393
# word semi-autobiographical is in word_rep at index 12393
# word: bugsy index: 12394
# word bugsy is in word_rep at index 12394
# word: caterer index: 12395
# word caterer is in word_rep at index 12395
# word: naïveté index: 12396
# word naïveté is in word_rep at index 12396
# word: robots index: 12397
# word robots is in word_rep at index 12397
# word: 3\/4th index: 12398
# word: spry index: 12399
# word spry is in word_rep at index 12399
# word: 2001 index: 12400
# word 2001 is in word_rep at index 12400
# word: sequel-for-the-sake index: 12401
# word: of-a-sequel index: 12402
# word: kalvert index: 12403
# word: 1958 index: 12404
# word 1958 is in word_rep at index 12404
# word: coburn index: 12405
# word coburn is in word_rep at index 12405
# word: inconceivable index: 12406
# word inconceivable is in word_rep at index 12406
# word: kills index: 12407
# word kills is in word_rep at index 12407
# word: no-surprise index: 12408
# word: ritter index: 12409
# word ritter is in word_rep at index 12409
# word: addresses index: 12410
# word addresses is in word_rep at index 12410
# word: herrings index: 12411
# word herrings is in word_rep at index 12411
# word: register index: 12412
# word register is in word_rep at index 12412
# word: mouthpieces index: 12413
# word mouthpieces is in word_rep at index 12413
# word: motifs index: 12414
# word motifs is in word_rep at index 12414
# word: achieved index: 12415
# word achieved is in word_rep at index 12415
# word: lottery index: 12416
# word lottery is in word_rep at index 12416
# word: metal index: 12417
# word metal is in word_rep at index 12417
# word: fireballs index: 12418
# word fireballs is in word_rep at index 12418
# word: ahem index: 12419
# word ahem is in word_rep at index 12419
# word: ailments index: 12420
# word ailments is in word_rep at index 12420
# word: uninflected index: 12421
# word uninflected is in word_rep at index 12421
# word: ambitiously index: 12422
# word ambitiously is in word_rep at index 12422
# word: abused index: 12423
# word abused is in word_rep at index 12423
# word: autistic index: 12424
# word autistic is in word_rep at index 12424
# word: appearing index: 12425
# word appearing is in word_rep at index 12425
# word: cynic index: 12426
# word cynic is in word_rep at index 12426
# word: groaner index: 12427
# word groaner is in word_rep at index 12427
# word: zero-dimensional index: 12428
# word zero-dimensional is in word_rep at index 12428
# word: dissipated index: 12429
# word dissipated is in word_rep at index 12429
# word: clyde index: 12430
# word clyde is in word_rep at index 12430
# word: barrow index: 12431
# word barrow is in word_rep at index 12431
# word: leafing index: 12432
# word leafing is in word_rep at index 12432
# word: accompanied index: 12433
# word accompanied is in word_rep at index 12433
# word: sketchiest index: 12434
# word sketchiest is in word_rep at index 12434
# word: captions index: 12435
# word captions is in word_rep at index 12435
# word: half-lit index: 12436
# word: dorm index: 12437
# word dorm is in word_rep at index 12437
# word: coda index: 12438
# word coda is in word_rep at index 12438
# word: policy index: 12439
# word policy is in word_rep at index 12439
# word: fangoria index: 12440
# word fangoria is in word_rep at index 12440
# word: subscriber index: 12441
# word subscriber is in word_rep at index 12441
# word: janey index: 12442
# word janey is in word_rep at index 12442
# word: obligations index: 12443
# word obligations is in word_rep at index 12443
# word: guessable index: 12444
# word: morbidity index: 12445
# word morbidity is in word_rep at index 12445
# word: asia index: 12446
# word asia is in word_rep at index 12446
# word: shu index: 12447
# word shu is in word_rep at index 12447
# word: insufficiently index: 12448
# word insufficiently is in word_rep at index 12448
# word: hibernation index: 12449
# word hibernation is in word_rep at index 12449
# word: skidding index: 12450
# word skidding is in word_rep at index 12450
# word: limps index: 12451
# word limps is in word_rep at index 12451
# word: squirm-inducing index: 12452
# word: fish-out-of-water index: 12453
# word: cesspool index: 12454
# word cesspool is in word_rep at index 12454
# word: tolstoy index: 12455
# word tolstoy is in word_rep at index 12455
# word: groupies index: 12456
# word groupies is in word_rep at index 12456
# word: heathers index: 12457
# word heathers is in word_rep at index 12457
# word: flounders index: 12458
# word flounders is in word_rep at index 12458
# word: plato index: 12459
# word plato is in word_rep at index 12459
# word: therefore index: 12460
# word therefore is in word_rep at index 12460
# word: miniseries index: 12461
# word miniseries is in word_rep at index 12461
# word: astronomically index: 12462
# word astronomically is in word_rep at index 12462
# word: slimed index: 12463
# word slimed is in word_rep at index 12463
# word: barbed index: 12464
# word barbed is in word_rep at index 12464
# word: poo-poo index: 12465
# word: sleep-inducingly index: 12466
# word: slow-paced index: 12467
# word slow-paced is in word_rep at index 12467
# word: phoney-feeling index: 12468
# word: cipherlike index: 12469
# word: ruthlessly index: 12470
# word ruthlessly is in word_rep at index 12470
# word: pained index: 12471
# word pained is in word_rep at index 12471
# word: dislikable index: 12472
# word dislikable is in word_rep at index 12472
# word: sociopathy index: 12473
# word sociopathy is in word_rep at index 12473
# word: scam index: 12474
# word scam is in word_rep at index 12474
# word: suckers index: 12475
# word suckers is in word_rep at index 12475
# word: 93 index: 12476
# word 93 is in word_rep at index 12476
# word: unrecoverable index: 12477
# word unrecoverable is in word_rep at index 12477
# word: recovering index: 12478
# word recovering is in word_rep at index 12478
# word: sorely index: 12479
# word sorely is in word_rep at index 12479
# word: careening index: 12480
# word careening is in word_rep at index 12480
# word: salvage index: 12481
# word salvage is in word_rep at index 12481
# word: landbound index: 12482
# word: gender-provoking index: 12483
# word: submerged index: 12484
# word submerged is in word_rep at index 12484
# word: peekaboo index: 12485
# word peekaboo is in word_rep at index 12485
# word: elves index: 12486
# word elves is in word_rep at index 12486
# word: pimps index: 12487
# word pimps is in word_rep at index 12487
# word: ho index: 12488
# word ho is in word_rep at index 12488
# word: boardwalk index: 12489
# word boardwalk is in word_rep at index 12489
# word: unifying index: 12490
# word unifying is in word_rep at index 12490
# word: unromantic index: 12491
# word unromantic is in word_rep at index 12491
# word: kiddie-oriented index: 12492
# word: gum index: 12493
# word gum is in word_rep at index 12493
# word: sneak index: 12494
# word sneak is in word_rep at index 12494
# word: deviously index: 12495
# word deviously is in word_rep at index 12495
# word: adopts index: 12496
# word adopts is in word_rep at index 12496
# word: guise index: 12497
# word guise is in word_rep at index 12497
# word: existing index: 12498
# word existing is in word_rep at index 12498
# word: coincidence index: 12499
# word coincidence is in word_rep at index 12499
# word: unrequited index: 12500
# word unrequited is in word_rep at index 12500
# word: half-hour index: 12501
# word half-hour is in word_rep at index 12501
# word: angst-ridden index: 12502
# word angst-ridden is in word_rep at index 12502
# word: covered index: 12503
# word covered is in word_rep at index 12503
# word: lewd index: 12504
# word lewd is in word_rep at index 12504
# word: useful index: 12505
# word useful is in word_rep at index 12505
# word: bang-the-drum index: 12506
# word: odoriferous index: 12507
# word odoriferous is in word_rep at index 12507
# word: crawl index: 12508
# word crawl is in word_rep at index 12508
# word: fist index: 12509
# word fist is in word_rep at index 12509
# word: anti-catholic index: 12510
# word anti-catholic is in word_rep at index 12510
# word: protestors index: 12511
# word protestors is in word_rep at index 12511
# word: gesturing index: 12512
# word gesturing is in word_rep at index 12512
# word: bedeviled index: 12513
# word bedeviled is in word_rep at index 12513
# word: miscalculates index: 12514
# word miscalculates is in word_rep at index 12514
# word: fiddle index: 12515
# word fiddle is in word_rep at index 12515
# word: melange index: 12516
# word melange is in word_rep at index 12516
# word: bid index: 12517
# word bid is in word_rep at index 12517
# word: treachery index: 12518
# word treachery is in word_rep at index 12518
# word: devotedly index: 12519
# word devotedly is in word_rep at index 12519
# word: pin-like index: 12520
# word: recreation index: 12521
# word recreation is in word_rep at index 12521
# word: scuttled index: 12522
# word scuttled is in word_rep at index 12522
# word: portraying index: 12523
# word portraying is in word_rep at index 12523
# word: devastation index: 12524
# word devastation is in word_rep at index 12524
# word: disease index: 12525
# word disease is in word_rep at index 12525
# word: faulty index: 12526
# word faulty is in word_rep at index 12526
# word: spotty index: 12527
# word spotty is in word_rep at index 12527
# word: stomps index: 12528
# word stomps is in word_rep at index 12528
# word: hobnail index: 12529
# word: natalie index: 12530
# word natalie is in word_rep at index 12530
# word: babbitt index: 12531
# word babbitt is in word_rep at index 12531
# word: motorized index: 12532
# word motorized is in word_rep at index 12532
# word: dewy-eyed index: 12533
# word: kid-movie index: 12534
# word: inauspicious index: 12535
# word inauspicious is in word_rep at index 12535
# word: mopes index: 12536
# word mopes is in word_rep at index 12536
# word: tract index: 12537
# word tract is in word_rep at index 12537
# word: meanderings index: 12538
# word meanderings is in word_rep at index 12538
# word: lessen index: 12539
# word lessen is in word_rep at index 12539
# word: psychodramatics index: 12540
# word: setpiece index: 12541
# word setpiece is in word_rep at index 12541
# word: conspicuously index: 12542
# word conspicuously is in word_rep at index 12542
# word: blowout index: 12543
# word blowout is in word_rep at index 12543
# word: downplaying index: 12544
# word downplaying is in word_rep at index 12544
# word: she-cute index: 12545
# word: troubled index: 12546
# word troubled is in word_rep at index 12546
# word: homicide index: 12547
# word homicide is in word_rep at index 12547
# word: scenarios index: 12548
# word scenarios is in word_rep at index 12548
# word: sermonize index: 12549
# word: okay index: 12550
# word okay is in word_rep at index 12550
# word: seventy-minute index: 12551
# word: avid index: 12552
# word avid is in word_rep at index 12552
# word: impatient index: 12553
# word impatient is in word_rep at index 12553
# word: strenuous index: 12554
# word strenuous is in word_rep at index 12554
# word: clinch index: 12555
# word clinch is in word_rep at index 12555
# word: razzie index: 12556
# word razzie is in word_rep at index 12556
# word: escapades index: 12557
# word escapades is in word_rep at index 12557
# word: gander index: 12558
# word gander is in word_rep at index 12558
# word: amuses index: 12559
# word amuses is in word_rep at index 12559
# word: realities index: 12560
# word realities is in word_rep at index 12560
# word: all-inclusive index: 12561
# word all-inclusive is in word_rep at index 12561
# word: uptight index: 12562
# word uptight is in word_rep at index 12562
# word: bores index: 12563
# word bores is in word_rep at index 12563
# word: expressly index: 12564
# word expressly is in word_rep at index 12564
# word: sewage index: 12565
# word sewage is in word_rep at index 12565
# word: shovel index: 12566
# word shovel is in word_rep at index 12566
# word: gullets index: 12567
# word gullets is in word_rep at index 12567
# word: simulate index: 12568
# word simulate is in word_rep at index 12568
# word: sustenance index: 12569
# word sustenance is in word_rep at index 12569
# word: court index: 12570
# word court is in word_rep at index 12570
# word: maneuvers index: 12571
# word maneuvers is in word_rep at index 12571
# word: palm index: 12572
# word palm is in word_rep at index 12572
# word: sc2 index: 12573
# word sc2 is in word_rep at index 12573
# word: autopilot index: 12574
# word autopilot is in word_rep at index 12574
# word: masters index: 12575
# word masters is in word_rep at index 12575
# word: dog-paddle index: 12576
# word: entering index: 12577
# word entering is in word_rep at index 12577
# word: synagogue index: 12578
# word synagogue is in word_rep at index 12578
# word: ramblings index: 12579
# word ramblings is in word_rep at index 12579
# word: smorgasbord index: 12580
# word smorgasbord is in word_rep at index 12580
# word: soliloquies index: 12581
# word soliloquies is in word_rep at index 12581
# word: spawned index: 12582
# word spawned is in word_rep at index 12582
# word: tantamount index: 12583
# word tantamount is in word_rep at index 12583
# word: sept. index: 12584
# word sept. is in word_rep at index 12584
# word: disney-style index: 12585
# word: wing index: 12586
# word wing is in word_rep at index 12586
# word: prayer index: 12587
# word prayer is in word_rep at index 12587
# word: hunky index: 12588
# word hunky is in word_rep at index 12588
# word: castle index: 12589
# word castle is in word_rep at index 12589
# word: sky index: 12590
# word sky is in word_rep at index 12590
# word: nurses index: 12591
# word nurses is in word_rep at index 12591
# word: olympic index: 12592
# word olympic is in word_rep at index 12592
# word: brain-deadening index: 12593
# word: hangover index: 12594
# word hangover is in word_rep at index 12594
# word: blustery index: 12595
# word blustery is in word_rep at index 12595
# word: flop index: 12596
# word flop is in word_rep at index 12596
# word: steam index: 12597
# word steam is in word_rep at index 12597
# word: substitutes index: 12598
# word substitutes is in word_rep at index 12598
# word: sanitised index: 12599
# word sanitised is in word_rep at index 12599
# word: surgeon index: 12600
# word surgeon is in word_rep at index 12600
# word: mends index: 12601
# word mends is in word_rep at index 12601
# word: decommissioned index: 12602
# word decommissioned is in word_rep at index 12602
# word: ear-splitting index: 12603
# word: crash-and-bash index: 12604
# word: overload index: 12605
# word overload is in word_rep at index 12605
# word: irreparably index: 12606
# word irreparably is in word_rep at index 12606
# word: schaefer index: 12607
# word schaefer is in word_rep at index 12607
# word: mid-to-low index: 12608
# word: betrayed index: 12609
# word betrayed is in word_rep at index 12609
# word: fleder index: 12610
# word fleder is in word_rep at index 12610
# word: aiello index: 12611
# word aiello is in word_rep at index 12611
# word: mumbles index: 12612
# word mumbles is in word_rep at index 12612
# word: guilt-trip index: 12613
# word: friggin index: 12614
# word friggin is in word_rep at index 12614
# word: garth index: 12615
# word garth is in word_rep at index 12615
# word: progressed index: 12616
# word progressed is in word_rep at index 12616
# word: dodge index: 12617
# word dodge is in word_rep at index 12617
# word: neeson index: 12618
# word neeson is in word_rep at index 12618
# word: capably index: 12619
# word capably is in word_rep at index 12619
# word: saddam index: 12620
# word saddam is in word_rep at index 12620
# word: hussein index: 12621
# word hussein is in word_rep at index 12621
# word: u.n. index: 12622
# word u.n. is in word_rep at index 12622
# word: permission index: 12623
# word permission is in word_rep at index 12623
# word: scummy index: 12624
# word scummy is in word_rep at index 12624
# word: ripoff index: 12625
# word ripoff is in word_rep at index 12625
# word: cronenberg index: 12626
# word cronenberg is in word_rep at index 12626
# word: videodrome index: 12627
# word videodrome is in word_rep at index 12627
# word: distressingly index: 12628
# word distressingly is in word_rep at index 12628
# word: horses index: 12629
# word horses is in word_rep at index 12629
# word: inadvertent index: 12630
# word inadvertent is in word_rep at index 12630
# word: salaries index: 12631
# word salaries is in word_rep at index 12631
# word: spliced index: 12632
# word spliced is in word_rep at index 12632
# word: 48 index: 12633
# word 48 is in word_rep at index 12633
# word: quasi-improvised index: 12634
# word: agape index: 12635
# word agape is in word_rep at index 12635
# word: punched index: 12636
# word punched is in word_rep at index 12636
# word: officially index: 12637
# word officially is in word_rep at index 12637
# word: bestial index: 12638
# word bestial is in word_rep at index 12638
# word: spinoff index: 12639
# word spinoff is in word_rep at index 12639
# word: dwindles index: 12640
# word dwindles is in word_rep at index 12640
# word: control-alt-delete index: 12641
# word: bleed index: 12642
# word bleed is in word_rep at index 12642
# word: underlies index: 12643
# word underlies is in word_rep at index 12643
# word: under-10 index: 12644
# word under-10 is in word_rep at index 12644
# word: keg index: 12645
# word keg is in word_rep at index 12645
# word: intimidated index: 12646
# word intimidated is in word_rep at index 12646
# word: spousal index: 12647
# word spousal is in word_rep at index 12647
# word: populating index: 12648
# word populating is in word_rep at index 12648
# word: meanspirited index: 12649
# word: cash index: 12650
# word cash is in word_rep at index 12650
# word: camouflaging index: 12651
# word camouflaging is in word_rep at index 12651
# word: greengrass index: 12652
# word greengrass is in word_rep at index 12652
# word: tad index: 12653
# word tad is in word_rep at index 12653
# word: intelligibility index: 12654
# word intelligibility is in word_rep at index 12654
# word: butterfingered index: 12655
# word: big-fisted index: 12656
# word: jez index: 12657
# word jez is in word_rep at index 12657
# word: butterworth index: 12658
# word butterworth is in word_rep at index 12658
# word: smallest index: 12659
# word smallest is in word_rep at index 12659
# word: sensitivities index: 12660
# word sensitivities is in word_rep at index 12660
# word: clamorous index: 12661
# word clamorous is in word_rep at index 12661
# word: forewarned index: 12662
# word forewarned is in word_rep at index 12662
# word: lake index: 12663
# word lake is in word_rep at index 12663
# word: afterwards index: 12664
# word afterwards is in word_rep at index 12664
# word: ragged index: 12665
# word ragged is in word_rep at index 12665
# word: gushy index: 12666
# word gushy is in word_rep at index 12666
# word: m index: 12667
# word m is in word_rep at index 12667
# word: s index: 12668
# word s is in word_rep at index 12668
# word: leonard index: 12669
# word leonard is in word_rep at index 12669
# word: uphill index: 12670
# word uphill is in word_rep at index 12670
# word: poorly-constructed index: 12671
# word: laughingly index: 12672
# word laughingly is in word_rep at index 12672
# word: good-looking index: 12673
# word good-looking is in word_rep at index 12673
# word: fork index: 12674
# word fork is in word_rep at index 12674
# word: rediscovers index: 12675
# word rediscovers is in word_rep at index 12675
# word: aptitude index: 12676
# word aptitude is in word_rep at index 12676
# word: abdul index: 12677
# word abdul is in word_rep at index 12677
# word: malik index: 12678
# word malik is in word_rep at index 12678
# word: abbott index: 12679
# word abbott is in word_rep at index 12679
# word: ernest index: 12680
# word ernest is in word_rep at index 12680
# word: tron index: 12681
# word tron is in word_rep at index 12681
# word: initially index: 12682
# word initially is in word_rep at index 12682
# word: shunji index: 12683
# word shunji is in word_rep at index 12683
# word: payoffs index: 12684
# word payoffs is in word_rep at index 12684
# word: jump-in-your-seat index: 12685
# word: backseat index: 12686
# word backseat is in word_rep at index 12686
# word: coriat index: 12687
# word: coinage index: 12688
# word coinage is in word_rep at index 12688
# word: pawn index: 12689
# word pawn is in word_rep at index 12689
# word: disabilities index: 12690
# word disabilities is in word_rep at index 12690
# word: hypertime index: 12691
# word hypertime is in word_rep at index 12691
# word: reverse index: 12692
# word reverse is in word_rep at index 12692
# word: trope index: 12693
# word trope is in word_rep at index 12693
# word: avalanches index: 12694
# word avalanches is in word_rep at index 12694
# word: fuzziness index: 12695
# word fuzziness is in word_rep at index 12695
# word: whoop index: 12696
# word whoop is in word_rep at index 12696
# word: shankman index: 12697
# word shankman is in word_rep at index 12697
# word: janszen index: 12698
# word janszen is in word_rep at index 12698
# word: bungle index: 12699
# word bungle is in word_rep at index 12699
# word: parables index: 12700
# word parables is in word_rep at index 12700
# word: brats index: 12701
# word brats is in word_rep at index 12701
# word: peopled index: 12702
# word peopled is in word_rep at index 12702
# word: uncool index: 12703
# word uncool is in word_rep at index 12703
# word: gadzooks index: 12704
# word gadzooks is in word_rep at index 12704
# word: entrée index: 12705
# word entrée is in word_rep at index 12705
# word: flavorless index: 12706
# word flavorless is in word_rep at index 12706
# word: conceptions index: 12707
# word conceptions is in word_rep at index 12707
# word: impressionistic index: 12708
# word impressionistic is in word_rep at index 12708
# word: point-of-view index: 12709
# word point-of-view is in word_rep at index 12709
# word: slow-motion index: 12710
# word slow-motion is in word_rep at index 12710
# word: quick-cut index: 12711
# word: splatterfests index: 12712
# word: log index: 12713
# word log is in word_rep at index 12713
# word: user-friendly index: 12714
# word user-friendly is in word_rep at index 12714
# word: disreputable index: 12715
# word disreputable is in word_rep at index 12715
# word: dampened index: 12716
# word dampened is in word_rep at index 12716
# word: substandard index: 12717
# word substandard is in word_rep at index 12717
# word: megaplexes index: 12718
# word megaplexes is in word_rep at index 12718
# word: oh-those-wacky-brits index: 12719
# word: ushered index: 12720
# word ushered is in word_rep at index 12720
# word: femme index: 12721
# word femme is in word_rep at index 12721
# word: fatale index: 12722
# word fatale is in word_rep at index 12722
# word: bait-and-switch index: 12723
# word: misunderstanding index: 12724
# word misunderstanding is in word_rep at index 12724
# word: marivaux index: 12725
# word marivaux is in word_rep at index 12725
# word: neo-noir index: 12726
# word neo-noir is in word_rep at index 12726
# word: sontag index: 12727
# word sontag is in word_rep at index 12727
# word: stern index: 12728
# word stern is in word_rep at index 12728
# word: personable index: 12729
# word personable is in word_rep at index 12729
# word: beer index: 12730
# word beer is in word_rep at index 12730
# word: uma index: 12731
# word uma is in word_rep at index 12731
# word: highly-praised index: 12732
# word: misfortune index: 12733
# word misfortune is in word_rep at index 12733
# word: schiffer index: 12734
# word schiffer is in word_rep at index 12734
# word: hossein index: 12735
# word hossein is in word_rep at index 12735
# word: amini index: 12736
# word amini is in word_rep at index 12736
# word: reconceptualize index: 12737
# word: barriers index: 12738
# word barriers is in word_rep at index 12738
# word: requires index: 12739
# word requires is in word_rep at index 12739
# word: oh-so-important index: 12740
# word: reinforcement index: 12741
# word reinforcement is in word_rep at index 12741
# word: leaning index: 12742
# word leaning is in word_rep at index 12742
# word: badly-rendered index: 12743
# word: grandfather index: 12744
# word grandfather is in word_rep at index 12744
# word: nosedive index: 12745
# word nosedive is in word_rep at index 12745
# word: infirmity index: 12746
# word infirmity is in word_rep at index 12746
# word: heart-string index: 12747
# word: pop-influenced index: 12748
# word pop-influenced is in word_rep at index 12748
# word: prank index: 12749
# word prank is in word_rep at index 12749
# word: cirulnick index: 12750
# word: novelist index: 12751
# word novelist is in word_rep at index 12751
# word: thulani index: 12752
# word thulani is in word_rep at index 12752
# word: artsploitation index: 12753
# word: bona index: 12754
# word bona is in word_rep at index 12754
# word: fide index: 12755
# word fide is in word_rep at index 12755
# word: groaners index: 12756
# word groaners is in word_rep at index 12756
# word: eternal index: 12757
# word eternal is in word_rep at index 12757
# word: pique index: 12758
# word pique is in word_rep at index 12758
# word: disgust index: 12759
# word disgust is in word_rep at index 12759
# word: grievous index: 12760
# word grievous is in word_rep at index 12760
# word: circles index: 12761
# word circles is in word_rep at index 12761
# word: obsessively index: 12762
# word obsessively is in word_rep at index 12762
# word: spout index: 12763
# word spout is in word_rep at index 12763
# word: wail index: 12764
# word wail is in word_rep at index 12764
# word: cadence index: 12765
# word cadence is in word_rep at index 12765
# word: fifteen-year-old index: 12766
# word fifteen-year-old is in word_rep at index 12766
# word: suicidal index: 12767
# word suicidal is in word_rep at index 12767
# word: bravura index: 12768
# word bravura is in word_rep at index 12768
# word: wearisome index: 12769
# word wearisome is in word_rep at index 12769
# word: and-miss index: 12770
# word: projection index: 12771
# word projection is in word_rep at index 12771
# word: ki-deok index: 12772
# word: regular index: 12773
# word regular is in word_rep at index 12773
# word: bouts index: 12774
# word bouts is in word_rep at index 12774
# word: defensible index: 12775
# word defensible is in word_rep at index 12775
# word: made-for-movie index: 12776
# word: evaluate index: 12777
# word evaluate is in word_rep at index 12777
# word: 2455 index: 12778
# word 2455 is in word_rep at index 12778
# word: crossed index: 12779
# word crossed is in word_rep at index 12779
# word: messenger index: 12780
# word messenger is in word_rep at index 12780
# word: asset index: 12781
# word asset is in word_rep at index 12781
# word: atrocities index: 12782
# word atrocities is in word_rep at index 12782
# word: leaks index: 12783
# word leaks is in word_rep at index 12783
# word: treacle index: 12784
# word treacle is in word_rep at index 12784
# word: rogue index: 12785
# word rogue is in word_rep at index 12785
# word: assassins index: 12786
# word assassins is in word_rep at index 12786
# word: agency index: 12787
# word agency is in word_rep at index 12787
# word: boss index: 12788
# word boss is in word_rep at index 12788
# word: amnesiac index: 12789
# word amnesiac is in word_rep at index 12789
# word: damon\/bourne index: 12790
# word: profundities index: 12791
# word profundities is in word_rep at index 12791
# word: tides index: 12792
# word tides is in word_rep at index 12792
# word: burdened index: 12793
# word burdened is in word_rep at index 12793
# word: accessibility index: 12794
# word accessibility is in word_rep at index 12794
# word: eighth-grader index: 12795
# word: versace index: 12796
# word versace is in word_rep at index 12796
# word: remained index: 12797
# word remained is in word_rep at index 12797
# word: collage index: 12798
# word collage is in word_rep at index 12798
# word: dim index: 12799
# word dim is in word_rep at index 12799
# word: echo index: 12800
# word echo is in word_rep at index 12800
# word: unsalvageability index: 12801
# word: anarchy index: 12802
# word anarchy is in word_rep at index 12802
# word: dumplings index: 12803
# word dumplings is in word_rep at index 12803
# word: glamorous index: 12804
# word glamorous is in word_rep at index 12804
# word: thrusts index: 12805
# word thrusts is in word_rep at index 12805
# word: moldering index: 12806
# word moldering is in word_rep at index 12806
# word: demonic index: 12807
# word demonic is in word_rep at index 12807
# word: rinzler index: 12808
# word rinzler is in word_rep at index 12808
# word: inhalant index: 12809
# word inhalant is in word_rep at index 12809
# word: blackout index: 12810
# word blackout is in word_rep at index 12810
# word: transfigures index: 12811
# word: unchanged index: 12812
# word unchanged is in word_rep at index 12812
# word: detractors index: 12813
# word detractors is in word_rep at index 12813
# word: august index: 12814
# word august is in word_rep at index 12814
# word: humidity index: 12815
# word humidity is in word_rep at index 12815
# word: café index: 12816
# word café is in word_rep at index 12816
# word: overhearing index: 12817
# word overhearing is in word_rep at index 12817
# word: late-twenty-somethings index: 12818
# word: natter index: 12819
# word natter is in word_rep at index 12819
# word: tables index: 12820
# word tables is in word_rep at index 12820
# word: all-over-the-map index: 12821
# word: pared index: 12822
# word pared is in word_rep at index 12822
# word: tv-movie index: 12823
# word tv-movie is in word_rep at index 12823
# word: chapter index: 12824
# word chapter is in word_rep at index 12824
# word: playwright index: 12825
# word playwright is in word_rep at index 12825
# word: drinker index: 12826
# word drinker is in word_rep at index 12826
# word: represent index: 12827
# word represent is in word_rep at index 12827
# word: exemplify index: 12828
# word exemplify is in word_rep at index 12828
# word: laziest index: 12829
# word laziest is in word_rep at index 12829
# word: meager index: 12830
# word meager is in word_rep at index 12830
# word: bewildered index: 12831
# word bewildered is in word_rep at index 12831
# word: spookily index: 12832
# word spookily is in word_rep at index 12832
# word: abrupt index: 12833
# word abrupt is in word_rep at index 12833
# word: glucose index: 12834
# word glucose is in word_rep at index 12834
# word: cello index: 12835
# word cello is in word_rep at index 12835
# word: culled index: 12836
# word culled is in word_rep at index 12836
# word: cold-hearted index: 12837
# word cold-hearted is in word_rep at index 12837
# word: fax index: 12838
# word fax is in word_rep at index 12838
# word: sodden index: 12839
# word sodden is in word_rep at index 12839
# word: priggish index: 12840
# word priggish is in word_rep at index 12840
# word: lethargically index: 12841
# word lethargically is in word_rep at index 12841
# word: renewal index: 12842
# word renewal is in word_rep at index 12842
# word: ankle-deep index: 12843
# word: 50-million index: 12844
# word 50-million is in word_rep at index 12844
# word: third-person index: 12845
# word third-person is in word_rep at index 12845
# word: prettiest index: 12846
# word prettiest is in word_rep at index 12846
# word: kendall index: 12847
# word kendall is in word_rep at index 12847
# word: decter index: 12848
# word decter is in word_rep at index 12848
# word: morsels index: 12849
# word morsels is in word_rep at index 12849
# word: heaped index: 12850
# word heaped is in word_rep at index 12850
# word: reap index: 12851
# word reap is in word_rep at index 12851
# word: unfairly index: 12852
# word unfairly is in word_rep at index 12852
# word: fabricated index: 12853
# word fabricated is in word_rep at index 12853
# word: violated index: 12854
# word violated is in word_rep at index 12854
# word: targets index: 12855
# word targets is in word_rep at index 12855
# word: raunch-fests index: 12856
# word: unmentionables index: 12857
# word unmentionables is in word_rep at index 12857
# word: outage index: 12858
# word outage is in word_rep at index 12858
# word: molehill index: 12859
# word molehill is in word_rep at index 12859
# word: restate index: 12860
# word restate is in word_rep at index 12860
# ...
# word: rough-hewn index: 14583
# word rough-hewn is in word_rep at index 14583
# word: andie index: 14584
# word andie is in word_rep at index 14584
# word: histrionic index: 14585
# word histrionic is in word_rep at index 14585
# word: eludes index: 14586
# word eludes is in word_rep at index 14586
# word: affinity index: 14587
# word affinity is in word_rep at index 14587
# word: fathom index: 14588
# word fathom is in word_rep at index 14588
# word: applegate index: 14589
# word applegate is in word_rep at index 14589
# word: posey index: 14590
# word posey is in word_rep at index 14590
# word: three-minute index: 14591
# word three-minute is in word_rep at index 14591
# word: 50-year-old index: 14592
# word 50-year-old is in word_rep at index 14592
# word: manager index: 14593
# word manager is in word_rep at index 14593
# word: dwells index: 14594
# word dwells is in word_rep at index 14594
# word: crossing-over index: 14595
# word: mumbo index: 14596
# word mumbo is in word_rep at index 14596
# word: flog index: 14597
# word flog is in word_rep at index 14597
# word: obligation index: 14598
# word obligation is in word_rep at index 14598
# word: pin index: 14599
# word pin is in word_rep at index 14599
# word: grenade index: 14600
# word grenade is in word_rep at index 14600
# word: ransacked index: 14601
# word ransacked is in word_rep at index 14601
# word: sense-spinning index: 14602
# word: one-trick index: 14603
# word: pony index: 14604
# word pony is in word_rep at index 14604
# word: softheaded index: 14605
# word: metaphysical index: 14606
# word metaphysical is in word_rep at index 14606
# word: trudge index: 14607
# word trudge is in word_rep at index 14607
# word: rode index: 14608
# word rode is in word_rep at index 14608
# word: zipper index: 14609
# word zipper is in word_rep at index 14609
# word: corn index: 14610
# word corn is in word_rep at index 14610
# word: extra-large index: 14611
# word extra-large is in word_rep at index 14611
# word: full-frontal index: 14612
# word full-frontal is in word_rep at index 14612
# word: shriveled index: 14613
# word shriveled is in word_rep at index 14613
# word: purports index: 14614
# word purports is in word_rep at index 14614
# word: actioners index: 14615
# word: schmucks index: 14616
# word schmucks is in word_rep at index 14616
# word: sporting index: 14617
# word sporting is in word_rep at index 14617
# word: hole-ridden index: 14618
# word: pact index: 14619
# word pact is in word_rep at index 14619
# word: negative index: 14620
# word negative is in word_rep at index 14620
# word: orchestrating index: 14621
# word orchestrating is in word_rep at index 14621
# word: ward index: 14622
# word ward is in word_rep at index 14622
# word: borscht index: 14623
# word borscht is in word_rep at index 14623
# word: schtick index: 14624
# word schtick is in word_rep at index 14624
# word: lds index: 14625
# word lds is in word_rep at index 14625
# word: undemanding index: 14626
# word undemanding is in word_rep at index 14626
# word: armchair index: 14627
# word armchair is in word_rep at index 14627
# word: tourists index: 14628
# word tourists is in word_rep at index 14628
# word: hanukkah index: 14629
# word hanukkah is in word_rep at index 14629
# word: fried index: 14630
# word fried is in word_rep at index 14630
# word: period-piece index: 14631
# word: blarney index: 14632
# word blarney is in word_rep at index 14632
# word: descriptions index: 14633
# word descriptions is in word_rep at index 14633
# word: traps index: 14634
# word traps is in word_rep at index 14634
# word: ransom index: 14635
# word ransom is in word_rep at index 14635
# word: justifying index: 14636
# word justifying is in word_rep at index 14636
# word: activities index: 14637
# word activities is in word_rep at index 14637
# word: prisoners index: 14638
# word prisoners is in word_rep at index 14638
# word: valentine index: 14639
# word valentine is in word_rep at index 14639
# word: top-heavy index: 14640
# word top-heavy is in word_rep at index 14640
# word: blazing index: 14641
# word blazing is in word_rep at index 14641
# word: cheatfully index: 14642
# word: bloodsucker index: 14643
# word bloodsucker is in word_rep at index 14643
# word: drunk index: 14644
# word drunk is in word_rep at index 14644
# word: distressing index: 14645
# word distressing is in word_rep at index 14645
# word: robotically index: 14646
# word robotically is in word_rep at index 14646
# word: italicized index: 14647
# word italicized is in word_rep at index 14647
# word: truth-in-advertising index: 14648
# word: hounds index: 14649
# word hounds is in word_rep at index 14649
# word: hustling index: 14650
# word hustling is in word_rep at index 14650
# word: characterisation index: 14651
# word characterisation is in word_rep at index 14651
# word: sacrificed index: 14652
# word sacrificed is in word_rep at index 14652
# word: muy index: 14653
# word muy is in word_rep at index 14653
# word: loco index: 14654
# word loco is in word_rep at index 14654
# word: truckzilla index: 14655
# word: cryin index: 14656
# word cryin is in word_rep at index 14656
# word: mishandle index: 14657
# word mishandle is in word_rep at index 14657
# word: physician index: 14658
# word physician is in word_rep at index 14658
# word: 'n index: 14659
# word 'n is in word_rep at index 14659
# word: milquetoast index: 14660
# word milquetoast is in word_rep at index 14660
# word: feel-bad index: 14661
# word: items index: 14662
# word items is in word_rep at index 14662
# word: winking index: 14663
# word winking is in word_rep at index 14663
# word: abiding index: 14664
# word abiding is in word_rep at index 14664
# word: hallucinogenic index: 14665
# word hallucinogenic is in word_rep at index 14665
# word: acres index: 14666
# word acres is in word_rep at index 14666
# word: haute index: 14667
# word haute is in word_rep at index 14667
# word: couture index: 14668
# word couture is in word_rep at index 14668
# word: conceal index: 14669
# word conceal is in word_rep at index 14669
# word: kate index: 14670
# word kate is in word_rep at index 14670
# word: janine index: 14671
# word janine is in word_rep at index 14671
# word: all-woman index: 14672
# word all-woman is in word_rep at index 14672
# word: puzzled index: 14673
# word puzzled is in word_rep at index 14673
# word: pressure index: 14674
# word pressure is in word_rep at index 14674
# word: cooker index: 14675
# word cooker is in word_rep at index 14675
# word: horrified index: 14676
# word horrified is in word_rep at index 14676
# word: cellophane-pop index: 14677
# word: gentlemen index: 14678
# word gentlemen is in word_rep at index 14678
# word: stains index: 14679
# word stains is in word_rep at index 14679
# word: agile index: 14680
# word agile is in word_rep at index 14680
# word: rodan index: 14681
# word rodan is in word_rep at index 14681
# word: juliet index: 14682
# word juliet is in word_rep at index 14682
# word: stevenon index: 14683
# word: pamela index: 14684
# word pamela is in word_rep at index 14684
# word: roller index: 14685
# word roller is in word_rep at index 14685
# word: coaster index: 14686
# word coaster is in word_rep at index 14686
# word: startled index: 14687
# word startled is in word_rep at index 14687
# word: dozing index: 14688
# word dozing is in word_rep at index 14688
# word: re-working index: 14689
# word re-working is in word_rep at index 14689
# word: shouting index: 14690
# word shouting is in word_rep at index 14690
# word: chore index: 14691
# word chore is in word_rep at index 14691
# word: definitions index: 14692
# word definitions is in word_rep at index 14692
# word: waster index: 14693
# word waster is in word_rep at index 14693
# word: hurried index: 14694
# word hurried is in word_rep at index 14694
# word: 1959 index: 14695
# word 1959 is in word_rep at index 14695
# word: godzilla index: 14696
# word godzilla is in word_rep at index 14696
# word: commenting index: 14697
# word commenting is in word_rep at index 14697
# word: electrocute index: 14698
# word electrocute is in word_rep at index 14698
# word: dismember index: 14699
# word dismember is in word_rep at index 14699
# word: avert index: 14700
# word avert is in word_rep at index 14700
# word: yeah index: 14701
# word yeah is in word_rep at index 14701
# word: well-defined index: 14702
# word well-defined is in word_rep at index 14702
# word: torments index: 14703
# word torments is in word_rep at index 14703
# word: operatic index: 14704
# word operatic is in word_rep at index 14704
# word: online index: 14705
# word online is in word_rep at index 14705
# word: laptops index: 14706
# word laptops is in word_rep at index 14706
# word: plans index: 14707
# word plans is in word_rep at index 14707
# word: amassed index: 14708
# word amassed is in word_rep at index 14708
# word: a.s. index: 14709
# word a.s. is in word_rep at index 14709
# word: head-on index: 14710
# word head-on is in word_rep at index 14710
# word: trading index: 14711
# word trading is in word_rep at index 14711
# word: reverence index: 14712
# word reverence is in word_rep at index 14712
# word: altman index: 14713
# word altman is in word_rep at index 14713
# word: alternates index: 14714
# word alternates is in word_rep at index 14714
# word: introspection index: 14715
# word introspection is in word_rep at index 14715
# word: benevolent index: 14716
# word benevolent is in word_rep at index 14716
# word: plea index: 14717
# word plea is in word_rep at index 14717
# word: democracy index: 14718
# word democracy is in word_rep at index 14718
# word: blushing index: 14719
# word blushing is in word_rep at index 14719
# word: gushing index: 14720
# word gushing is in word_rep at index 14720
# word: squirts index: 14721
# word squirts is in word_rep at index 14721
# word: best-sustained index: 14722
# word: chillingly index: 14723
# word chillingly is in word_rep at index 14723
# word: book-on-tape index: 14724
# word: abridged index: 14725
# word abridged is in word_rep at index 14725
# word: brothers-style index: 14726
# word: down-and-dirty index: 14727
# word: laugher index: 14728
# word laugher is in word_rep at index 14728
# word: giants index: 14729
# word giants is in word_rep at index 14729
# word: frightfest index: 14730
# word frightfest is in word_rep at index 14730
# word: italicizes index: 14731
# word: vainglorious index: 14732
# word vainglorious is in word_rep at index 14732
# word: teen-speak index: 14733
# word: gibberish index: 14734
# word gibberish is in word_rep at index 14734
# word: busts index: 14735
# word busts is in word_rep at index 14735
# word: comfy index: 14736
# word comfy is in word_rep at index 14736
# word: symptom index: 14737
# word symptom is in word_rep at index 14737
# word: loser index: 14738
# word loser is in word_rep at index 14738
# word: favored index: 14739
# word favored is in word_rep at index 14739
# word: moaning index: 14740
# word moaning is in word_rep at index 14740
# word: spiderman index: 14741
# word spiderman is in word_rep at index 14741
# word: domineering index: 14742
# word domineering is in word_rep at index 14742
# word: well-structured index: 14743
# word well-structured is in word_rep at index 14743
# word: hardest index: 14744
# word hardest is in word_rep at index 14744
# word: argentinian index: 14745
# word argentinian is in word_rep at index 14745
# word: elegiac index: 14746
# word elegiac is in word_rep at index 14746
# word: uplifter index: 14747
# word: masala index: 14748
# word masala is in word_rep at index 14748
# word: featherweight index: 14749
# word featherweight is in word_rep at index 14749
# word: well-edited index: 14750
# word: standout index: 14751
# word standout is in word_rep at index 14751
# word: audacious-impossible index: 14752
# word: freak-out index: 14753
# word: cornball index: 14754
# word cornball is in word_rep at index 14754
# word: true-blue index: 14755
# word: peerlessly index: 14756
# word peerlessly is in word_rep at index 14756
# word: delirious index: 14757
# word delirious is in word_rep at index 14757
# word: spy-thriller index: 14758
# word: niblet index: 14759
# word: formuliac index: 14760
# word: dense index: 14761
# word dense is in word_rep at index 14761
# word: occasion index: 14762
# word occasion is in word_rep at index 14762
# word: mind-bender index: 14763
# word: disposible index: 14764
# word: aan index: 14765
# word aan is in word_rep at index 14765
# word: snoozer index: 14766
# word snoozer is in word_rep at index 14766
# word: execrable index: 14767
# word execrable is in word_rep at index 14767
# word: sensationalize index: 14768
# word sensationalize is in word_rep at index 14768
# word: bibbidy-bobbidi-bland index: 14769
# word: one-sidedness index: 14770
# word: thinly-conceived index: 14771
# word: well-meant index: 14772
# word: poo index: 14773
# word poo is in word_rep at index 14773
# word: garbled index: 14774
# word garbled is in word_rep at index 14774
# word: mush index: 14775
# word mush is in word_rep at index 14775
# word: conceited index: 14776
# word conceited is in word_rep at index 14776
# word: tonally index: 14777
# word tonally is in word_rep at index 14777
# word: non-mystery index: 14778
# word: under-rehearsed index: 14779
# word: irredeemably index: 14780
# word irredeemably is in word_rep at index 14780
# word: contraption index: 14781
# word contraption is in word_rep at index 14781
# word: less-than-thrilling index: 14782
# word: humbuggery index: 14783
# word: unrealistic index: 14784
# word unrealistic is in word_rep at index 14784
# word: two-bit index: 14785
# word two-bit is in word_rep at index 14785
# word: techno-tripe index: 14786
# word: reigns index: 14787
# word reigns is in word_rep at index 14787
# word: half-assed index: 14788
# word: abysmally index: 14789
# word abysmally is in word_rep at index 14789
# word: l index: 14790
# word l is in word_rep at index 14790
# word: ame index: 14791
# word ame is in word_rep at index 14791
# word: crushing index: 14792
# word crushing is in word_rep at index 14792
# word: plod index: 14793
# word plod is in word_rep at index 14793
# word: drudgery index: 14794
# word drudgery is in word_rep at index 14794
# word: reality-snubbing index: 14795
# word: degenerates index: 14796
# word degenerates is in word_rep at index 14796
# word: hogwash index: 14797
# word hogwash is in word_rep at index 14797
# word: road-and-buddy index: 14798
# word: slummer index: 14799
# word: drek index: 14800
# word: rashomon-for-dipsticks index: 14801
# word: mush-hearted index: 14802
# word: hippie-turned-yuppie index: 14803
# word: muttering index: 14804
# word muttering is in word_rep at index 14804
# word: dissing index: 14805
# word dissing is in word_rep at index 14805
# Cell type: LSTM, Hidden_size: 100, Num layers: 3, Dropout: 0.35, Bidirectional: Truem
# Training Started
# \ 033Epoch 0: Valid accuracy: 0.780889630317688m
# \ 033Epoch 1: Valid accuracy: 0.7792421579360962m
# \ 033Epoch 2: Valid accuracy: 0.7786930203437805m
# \ 033Epoch 3: Valid accuracy: 0.8001098036766052m
# \ 033Epoch 4: Valid accuracy: 0.7918726205825806m
# Finished Training
# Cell type: LSTM, Hidden_size: 100, Num layers: 3, Dropout: 0.35, Bidirectional: Truem
# Training Started
# \ 033Epoch 0: Valid accuracy: 0.7484898567199707m
# \ 033Epoch 1: Valid accuracy: 0.7605711221694946m
# \ 033Epoch 2: Valid accuracy: 0.774848997592926m
# \ 033Epoch 3: Valid accuracy: 0.7929708957672119m
# \ 033Epoch 4: Valid accuracy: 0.7973640561103821m
# Finished Training
# Cell type: LSTM, Hidden_size: 100, Num layers: 3, Dropout: 0.35, Bidirectional: Truem
# Training Started
# \ 033Epoch 0: Valid accuracy: 0.7797912955284119m
# \ 033Epoch 1: Valid accuracy: 0.7841845154762268m
# \ 033Epoch 2: Valid accuracy: 0.7946183681488037m
# \ 033Epoch 3: Valid accuracy: 0.7995606660842896m
# \ 033Epoch 4: Valid accuracy: 0.7814387679100037m
# Finished Training
# Cell type: LSTM, Hidden_size: 100, Num layers: 3, Dropout: 0.35, Bidirectional: Truem
# Training Started
# \ 033Epoch 0: Valid accuracy: 0.7677100300788879m
# \ 033Epoch 1: Valid accuracy: 0.7841845154762268m
# \ 033Epoch 2: Valid accuracy: 0.7951675057411194m
# \ 033Epoch 3: Valid accuracy: 0.7863811254501343m
# \ 033Epoch 4: Valid accuracy: 0.7880285382270813m
# Finished Training
# Cell type: LSTM, Hidden_size: 100, Num layers: 3, Dropout: 0.35, Bidirectional: Truem
# Training Started
# \ 033Epoch 0: Valid accuracy: 0.7710049152374268m
# \ 033Epoch 1: Valid accuracy: 0.7814387679100037m
# \ 033Epoch 2: Valid accuracy: 0.753981351852417m
# \ 033Epoch 3: Valid accuracy: 0.7995606660842896m
# \ 033Epoch 4: Valid accuracy: 0.7968149185180664m
# Finished Training
# Test Accuracy: 0.7821100950241089
